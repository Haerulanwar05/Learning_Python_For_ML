# %% [markdown]
# # Function

# %%
def function(<params>):
    <code>
    return <data>

# %%
def perkalian(a,b):
    x = a * b
    return x

# %%
perkalian(2,5)
# Out:
# 10

# %% [markdown]
# # Built in Function
# sebuah fungsi bawaan dari python

# %%
# seperti type()
buah = ['pisang','apel','salak']

# %%
type(buah)
# Out:
# list

# %%
# len untuk menghitung jumlah item dalam list
len(buah)
# Out:
# 3

# %%
# max mencari nilai max 
max([1,4,5,76,87,99])
# Out:
# 99

# %%
min([1,4,3,7,8,7])
# Out:
# 1

# %%
# range (start:stop:step)
for i in range (1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
