# %% [markdown]
# # If Statement

# %%
if <conditions>:
    <code>
elif <conditions>:
    <code>
else:
    <code>

# %%
umur = 13

if umur >= 18:
    print("kamu Dewasa")
elif umur >= 13:
    print("Kamu Remaja")
else:
    print("Kamu Anak-anak")
# Out:
# Kamu Remaja
